# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['harry', 'rohan', 'skillf','shubh'],
    "marks":[93, 55, 66, 65],
    "city":['rampur','kolkata','bareilly', 'antarctica']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0   harry     93      rampur
# 1   rohan     55     kolkata
# 2  skillf     66    bareilly
# 3   shubh     65  antarctica

# %%
df.to_csv('Pandas_tut.csv')

# %%
df.to_csv('pandas.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     93   rampur
# 1  rohan     55  kolkata

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     66    bareilly
# 3   shubh     65  antarctica

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   69.750000
# std    16.276261
# min    55.000000
# 25%    62.500000
# 50%    65.500000
# 75%    72.750000
# max    93.000000

# %%
harry = pd.read_csv('pdddd.csv')

# %%
harry
# Out:
#    Train No  speed        city
# 0    445666     93      rampur
# 1     55554     55     kolkata
# 2     33566     66    bareilly
# 3     56754     65  antarctica

# %%
harry['speed']
# Out:
# 0    93
# 1    55
# 2    66
# 3    65
# Name: speed, dtype: int64

# %%
harry['speed'][2]
# Out:
# 66

# %%
harry['speed'][2] = 123
# Out:
# C:\Users\majaz\AppData\Local\Temp\ipykernel_6456\1690926797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harry['speed'][2] = 123

# %%
harry
# Out:
#    Train No  speed        city
# 0    445666     93      rampur
# 1     55554     55     kolkata
# 2     33566    123    bareilly
# 3     56754     65  antarctica

# %%
harry.to_csv('harry.csv')

# %%
harry
# Out:
#    Train No  speed        city
# 0    445666     93      rampur
# 1     55554     55     kolkata
# 2     33566    123    bareilly
# 3     56754     65  antarctica

# %%
harry.index = ['first','second','third','fourth']

# %%
harry
# Out:
#         Train No  speed        city
# first     445666     93      rampur
# second     55554     55     kolkata
# third      33566    123    bareilly
# fourth     56754     65  antarctica

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.326643
# 1     0.032291
# 2     0.452072
# 3     0.486681
# 4     0.864327
# 5     0.967869
# 6     0.493171
# 7     0.088011
# 8     0.137951
# 9     0.800634
# 10    0.696578
# 11    0.673712
# 12    0.696535
# 13    0.809778
# 14    0.747971
# 15    0.991085
# 16    0.701029
# 17    0.253007
# 18    0.950629
# 19    0.132263
# 20    0.858662
# 21    0.567460
# 22    0.829295
# 23    0.846633
# 24    0.886614
# 25    0.445933
# 26    0.381914
# 27    0.499383
# 28    0.878956
# 29    0.106083
# 30    0.613171
# 31    0.221393
# 32    0.541321
# 33    0.949990
# dtype: float64

# %%
ser.dtype
# Out:
# dtype('float64')

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(345,6), index = np.arange(345))

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0.799244  0.218357  0.274310  0.712697  0.436879  0.205816
# 1    0.286656  0.423568  0.385571  0.037682  0.866443  0.903402
# 2    0.074588  0.376454  0.096460  0.767991  0.008418  0.034659
# 3    0.214111  0.856134  0.537431  0.048293  0.729606  0.558344
# 4    0.139330  0.851859  0.995929  0.273551  0.943711  0.829524
# ..        ...       ...       ...       ...       ...       ...
# 340  0.603521  0.680530  0.976339  0.657338  0.959638  0.763429
# 341  0.075359  0.196277  0.389242  0.280223  0.376830  0.209008
# 342  0.239132  0.897138  0.817838  0.841090  0.119957  0.350822
# 343  0.085939  0.152579  0.647957  0.920326  0.769800  0.426649
# 344  0.057908  0.004450  0.865449  0.528219  0.146114  0.123223
#
# [345 rows x 6 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4           5
# count
.214111  0.856134  0.537431  0.048293  0.729606  0.558344
# 4     0.13933  0.851859  0.995929  0.273551  0.943711  0.829524
# ..        ...       ...       ...       ...       ...       ...
# 340  0.603521  0.680530  0.976339  0.657338  0.959638  0.763429
# 341  0.075359  0.196277  0.389242  0.280223  0.376830  0.209008
# 342  0.239132  0.897138  0.817838  0.841090  0.119957  0.350822
# 343  0.085939  0.152579  0.647957  0.920326  0.769800  0.426649
# 344  0.057908  0.004450  0.865449  0.528219  0.146114  0.123223
#
# [345 rows x 6 columns]

# %%
newdf3 = newdf.copy() #newdf3 = newdf.copy() #

# %%
newdf3[0][1] = 334455666
# Out:
# C:\Users\majaz\AppData\Local\Temp\ipykernel_6456\4073222975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf3[0][1] = 334455666

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0      455666  0.218357  0.274310  0.712697  0.436879  0.205816
# 1    0.286656  0.423568  0.385571  0.037682  0.866443  0.903402
# 2    0.074588  0.376454  0.096460  0.767991  0.008418  0.034659
# 3    0.214111  0.856134  0.537431  0.048293  0.729606  0.558344
# 4     0.13933  0.851859  0.995929  0.273551  0.943711  0.829524
# ..        ...       ...       ...       ...       ...       ...
# 340  0.603521  0.680530  0.976339  0.657338  0.959638  0.763429
# 341  0.075359  0.196277  0.389242  0.280223  0.376830  0.209008
# 342  0.239132  0.897138  0.817838  0.841090  0.119957  0.350822
# 343  0.085939  0.152579  0.647957  0.920326  0.769800  0.426649
# 344  0.057908  0.004450  0.865449  0.528219  0.146114  0.123223
#
# [345 rows x 6 columns]

# %%
newdf.loc[0,0] = 456

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4         5
# 0       456  0.218357  0.274310  0.712697  0.436879  0.205816
# 1  0.286656  0.423568  0.385571  0.037682  0.866443  0.903402

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0       456  0.218357  0.274310  0.712697  0.436879  0.205816
# 1  0.286656  0.423568  0.385571  0.037682  0.866443  0.903402
# 2  0.074588  0.376454  0.096460  0.767991  0.008418  0.034659
# 3  0.214111  0.856134  0.537431  0.048293  0.729606  0.558344
# 4   0.13933  0.851859  0.995929  0.273551  0.943711  0.829524

# %%
newdf.drop(5, axis=1).head()
# Out:
#           0         1         2         3         4
# 0       456  0.218357  0.274310  0.712697  0.436879
# 1  0.286656  0.423568  0.385571  0.037682  0.866443
# 2  0.074588  0.376454  0.096460  0.767991  0.008418
# 3  0.214111  0.856134  0.537431  0.048293  0.729606
# 4   0.13933  0.851859  0.995929  0.273551  0.943711

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0       456  0.218357  0.274310  0.712697  0.436879  0.205816
# 1  0.286656  0.423568  0.385571  0.037682  0.866443  0.903402
# 2  0.074588  0.376454  0.096460  0.767991  0.008418  0.034659
# 3  0.214111  0.856134  0.537431  0.048293  0.729606  0.558344
# 4   0.13933  0.851859  0.995929  0.273551  0.943711  0.829524

# %%
newdf.loc[[0,1],[3,5]]
# Out:
#           3         5
# 0  0.712697  0.205816
# 1  0.037682  0.903402

# %%
newdf.loc[:,[3,5]].head()
# Out:
#           3         5
# 0  0.712697  0.205816
# 1  0.037682  0.903402
# 2  0.767991  0.034659
# 3  0.048293  0.558344
# 4  0.273551  0.829524

# %%
newdf.loc[(newdf[2] < 0.3) & (newdf[4] > 0.1)].head()
# Out:
#            0         1         2         3         4         5
# 0        456  0.218357  0.274310  0.712697  0.436879  0.205816
# 5   0.387777  0.357869  0.151750  0.580508  0.699898  0.761020
# 7   0.719995  0.270718  0.290089  0.271385  0.427690  0.836160
# 11  0.281875  0.292723  0.146195  0.133095  0.606538  0.513727
# 13  0.185756  0.170366  0.297588  0.262207  0.935781  0.863259

# %%
newdf.iloc[0,4] #loc is used to pick using index name but iloc is used to pick the element using index no.
# Out:
# 0.4368787204046457

# %%
newdf.drop([2,4], axis=1, inplace= True) #inplce is used to delete row or column permanently   inplace= True

# %%
newdf.head()
# Out:
#           0         1         3         5
# 0       456  0.218357  0.712697  0.205816
# 1  0.286656  0.423568  0.037682  0.903402
# 2  0.074588  0.376454  0.767991  0.034659
# 3  0.214111  0.856134  0.048293  0.558344
# 4   0.13933  0.851859  0.273551  0.829524

# %%
newdf.reset_index(drop=True, inplace= True)

# %%
newdf.isnull()
# Out:
#          0      1      3      5
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False
# ..     ...    ...    ...    ...
# 340  False  False  False  False
# 341  False  False  False  False
# 342  False  False  False  False
# 343  False  False  False  False
# 344  False  False  False  False
#
# [345 rows x 4 columns]

# %%
newdf.head()
# Out:
#           0         1         3         5
# 0       456  0.218357  0.712697  0.205816
# 1  0.286656  0.423568  0.037682  0.903402
# 2  0.074588  0.376454  0.767991  0.034659
# 3  0.214111  0.856134  0.048293  0.558344
# 4   0.13933  0.851859  0.273551  0.829524

# %%
newdf.loc[:,[1]] = None

# %%
newdf
# Out:
#             0     1         3         5
# 0         456  None  0.712697  0.205816
# 1    0.286656  None  0.037682  0.903402
# 2    0.074588  None  0.767991  0.034659
# 3    0.214111  None  0.048293  0.558344
# 4     0.13933  None  0.273551  0.829524
# ..        ...   ...       ...       ...
# 340  0.603521  None  0.657338  0.763429
# 341  0.075359  None  0.280223  0.209008
# 342  0.239132  None  0.841090  0.350822
# 343  0.085939  None  0.920326  0.426649
# 344  0.057908  None  0.528219  0.123223
#
# [345 rows x 4 columns]

# %%
newdf.isnull()
# Out:
#          0     1      3      5
# 0    False  True  False  False
# 1    False  True  False  False
# 2    False  True  False  False
# 3    False  True  False  False
# 4    False  True  False  False
# ..     ...   ...    ...    ...
# 340  False  True  False  False
# 341  False  True  False  False
# 342  False  True  False  False
# 343  False  True  False  False
# 344  False  True  False  False
#
# [345 rows x 4 columns]

# %%
df11 = pd.DataFrame({"name":['alfred','batman', np.nan],
                  "toy":[np.nan,'batmobile','bullwhip'],
                  "born":[pd.NaT,pd.Timestamp("1940-04-25"),pd.NaT]})

# %%
df11.head()
# Out:
#      name        toy       born
# 0  alfred        NaN        NaT
# 1  batman  batmobile 1940-04-25
# 2     NaN   bullwhip        NaT

# %%
df11.dropna(how='all') # if only dropna is run all the data having atleast one na is removed from dataset.
# Out:
#      name        toy       born
# 0  alfred        NaN        NaT
# 1  batman  batmobile 1940-04-25
# 2     NaN   bullwhip        NaT

# %%
df11.drop_duplicates(subset=['name'])
# Out:
#      name        toy       born
# 0  alfred        NaN        NaT
# 1  batman  batmobile 1940-04-25
# 2     NaN   bullwhip        NaT

# %%
df11.head()
# Out:
#      name        toy       born
# 0  alfred        NaN        NaT
# 1  batman  batmobile 1940-04-25
# 2     NaN   bullwhip        NaT

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df11['name'].value_counts(dropna=True)
# Out:
# alfred    1
# batman    1
# Name: name, dtype: int64

# %%
df11.notnull()
# Out:
#     name    toy   born
# 0   True  False  False
# 1   True   True   True
# 2  False   True  False
